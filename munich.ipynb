# %% [markdown]
# ## München analysis

# %% [markdown]
# ### Dataset HK_Cities

# %%
import pandas as pd
import matplotlib.pyplot as plt

hk_cities = pd.read_csv('./Data/HK_cities.csv', dtype={'plz': object})

df = pd.DataFrame(hk_cities)
# Out:
# /var/folders/5h/0pnj053913z2cl2pgkgr888h0000gp/T/ipykernel_46711/863109955.py:4: DtypeWarning: Columns (10,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   hk_cities = pd.read_csv('./Data/HK_cities.csv', dtype={'plz': object})

# %%
plz_city = pd.read_csv('./Data/zuordnung_plz_ort.csv', dtype={'plz': object})
df_plz_city = pd.DataFrame(plz_city)

merged_df = pd.merge(df, df_plz_city, how="left", on="plz")

munich_df = merged_df[merged_df['ort'] == 'München']
munich_df['adat_year'] = munich_df['adat'].astype(str).str[:4]
# Out:
# /var/folders/5h/0pnj053913z2cl2pgkgr888h0000gp/T/ipykernel_46711/562257369.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   munich_df['adat_year'] = munich_df['adat'].astype(str).str[:4]

# %%
average_price_sqm_per_year = munich_df.groupby('adat_year')['price_sqm'].mean()
plt.plot(average_price_sqm_per_year.index, average_price_sqm_per_year.values)
plt.xlabel("Year")
plt.ylabel('Mean price per Square Meter')
plt.title('Mean Price per Square Meter for House Purchases per Year')
plt.show()

number_of_transactions_per_year = munich_df.groupby('adat_year')['price_sqm'].count()
print(number_of_transactions_per_year)
plt.bar(number_of_transactions_per_year.index, number_of_transactions_per_year.values)
plt.xlabel("Year")
plt.ylabel('Number of transactions')
plt.title('Number of Transactions for House Purchases per Year')
plt.show()
# Out:
# adat_year
# 2007    1100
# 2008    1149
# 2009    1072
# 2010    1015
# 2011     961
# 2012    1000
# 2013     934
# 2014    1127
# 2015     980
# 2016     808
# 2017     824
# 2018     966
# 2019     992
# 2020     961
# 2021     637
# 2022     957
# Name: price_sqm, dtype: int64

# %% [markdown]
# ### Dataset WK_cities

# %%
wk_cities = pd.read_csv('./Data/WK_cities.csv', dtype={'plz': object})

df_cities = pd.DataFrame(wk_cities)
# Out:
# /var/folders/5h/0pnj053913z2cl2pgkgr888h0000gp/T/ipykernel_46711/4038894759.py:1: DtypeWarning: Columns (11,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   wk_cities = pd.read_csv('./Data/WK_cities.csv', dtype={'plz': object})

# %%
plz_city = pd.read_csv('./Data/zuordnung_plz_ort.csv', dtype={'plz': object})
df_plz_city = pd.DataFrame(plz_city)

merged_df = pd.merge(df_cities, df_plz_city, how="left", on="plz")

munich_cities_df = merged_df[merged_df['ort'] == 'München']
munich_cities_df['adat_year'] = munich_cities_df['adat'].astype(str).str[:4]
# Out:
# /var/folders/5h/0pnj053913z2cl2pgkgr888h0000gp/T/ipykernel_46711/3195186580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   munich_cities_df['adat_year'] = munich_cities_df['adat'].astype(str).str[:4]

# %%
average_price_sqm_per_year = munich_cities_df.groupby('adat_year')['price_sqm'].mean()
plt.plot(average_price_sqm_per_year.index, average_price_sqm_per_year.values)
plt.xlabel("Year")
plt.ylabel('Mean price per Square Meter')
plt.title('Mean Price per Square Meter for House Purchases per Year')
plt.show()

number_of_transactions_per_year = munich_cities_df.groupby('adat_year')['price_sqm'].count()
print(number_of_transactions_per_year)
plt.bar(number_of_transactions_per_year.index, number_of_transactions_per_year.values)
plt.xlabel("Year")
plt.ylabel('Number of transactions')
plt.title('Number of Transactions for Flat Purchases per Year')
plt.show()
# Out:
# adat_year
# 2007    11312
# 2008    10112
# 2009     9735
# 2010     9789
# 2011     9978
# 2012    10001
# 2013     9914
# 2014    10143
# 2015     9905
# 2016     9545
# 2017     9685
# 2018     9988
# 2019     9771
# 2020     9766
# 2021     9507
# 2022     9498
# Name: price_sqm, dtype: int64
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
